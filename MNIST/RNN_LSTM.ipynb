# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
import re
from IPython.display import display
import tensorflow as tf

plt.rc('font', family='Verdana')
# %matplotlib inline
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz

# %%
tf.Session().close()
train = pd.read_json("./train.json"))
test = pd.read_json("./test.json"))

trainimg = mnist.train.images
trainlabels = mnist.train.labels
testimg = mnist.test.images
testlabels = mnist.test.labels

n_input = 75
n_steps = 75
n_hidden = 128
n_classes = 2

learning_rate = 0.001
training_iters = 150000
batch_size = 100
display_step = 10

x = tf.placeholder(tf.float32, shape = [None, n_steps,n_input], name= 'x')
y = tf.placeholder(tf.float32, shape = [None, n_classes] , name='y')

weights = {
    'out' : tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
bias= {
    'out' : tf.Variable(tf.random_normal([n_classes]))
}

# %%
lstm_cell = tf.contrib.rnn.BasicLSTMCell(n_hidden, reuse = True)
outputs, states = tf.nn.dynamic_rnn(lstm_cell, inputs=x, dtype=tf.float32)
output = tf.reshape(tf.split(outputs, 28, axis=1, num=None, name='split')[-1],[-1,128])
pred = tf.matmul(output, weights['out']) + bias['out']

# %%
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels= y, logits = pred))
optimizer = tf.train.AdamOptimizer(learning_rate= learning_rate).minimize(cost)
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    step = 1
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
           
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    test_len = 128
    test_data = mnist.test.images.reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label}))
    sess.close()
# Out:
# Iter 1000, Minibatch Loss= 2.094573, Training Accuracy= 0.28000
# Iter 2000, Minibatch Loss= 1.737173, Training Accuracy= 0.37000
# Iter 3000, Minibatch Loss= 1.500616, Training Accuracy= 0.46000
# Iter 4000, Minibatch Loss= 1.264559, Training Accuracy= 0.58000
# Iter 5000, Minibatch Loss= 1.083438, Training Accuracy= 0.64000
# Iter 6000, Minibatch Loss= 0.910366, Training Accuracy= 0.69000
# Iter 7000, Minibatch Loss= 0.914225, Training Accuracy= 0.75000
# Iter 8000, Minibatch Loss= 0.683630, Training Accuracy= 0.83000
# Iter 9000, Minibatch Loss= 0.587980, Training Accuracy= 0.81000
# Iter 10000, Minibatch Loss= 0.706621, Training Accuracy= 0.73000
# Iter 11000, Minibatch Loss= 0.779013, Training Accuracy= 0.78000
# Iter 12000, Minibatch Loss= 0.462419, Training Accuracy= 0.83000
# Iter 13000, Minibatch Loss= 0.466140, Training Accuracy= 0.85000
# Iter 14000, Minibatch Loss= 0.372876, Training Accuracy= 0.85000
# Iter 15000, Minibatch Loss= 0.538129, Training Accuracy= 0.80000
# Iter 16000, Minibatch Loss= 0.390390, Training Accuracy= 0.87000
# Iter 17000, Minibatch Loss= 0.279223, Training Accuracy= 0.92000
# Iter 18000, Minibatch Loss= 0.282388, Training Accuracy= 0.89000
# Iter 19000, Minibatch Loss= 0.243142, Training Accuracy= 0.91000
# Iter 20000, Minibatch Loss= 0.258579, Training Accuracy= 0.94000
# Iter 21000, Minibatch Loss= 0.260022, Training Accuracy= 0.91000
# Iter 22000, Minibatch Loss= 0.231373, Training Accuracy= 0.91000
# Iter 23000, Minibatch Loss= 0.349346, Training Accuracy= 0.90000
# Iter 24000, Minibatch Loss= 0.397147, Training Accuracy= 0.87000
# Iter 25000, Minibatch Loss= 0.215878, Training Accuracy= 0.93000
# Iter 26000, Minibatch Loss= 0.282717, Training Accuracy= 0.89000
# Iter 27000, Minibatch Loss= 0.234476, Training Accuracy= 0.93000
# Iter 28000, Minibatch Loss= 0.181044, Training Accuracy= 0.94000
# Iter 29000, Minibatch Loss= 0.212721, Training Accuracy= 0.93000
# Iter 30000, Minibatch Loss= 0.166621, Training Accuracy= 0.92000
# Iter 31000, Minibatch Loss= 0.304166, Training Accuracy= 0.93000
# Iter 32000, Minibatch Loss= 0.318914, Training Accuracy= 0.88000
# Iter 33000, Minibatch Loss= 0.193309, Training Accuracy= 0.95000
# Iter 34000, Minibatch Loss= 0.270326, Training Accuracy= 0.93000
# Iter 35000, Minibatch Loss= 0.203842, Training Accuracy= 0.93000
# Iter 36000, Minibatch Loss= 0.144561, Training Accuracy= 0.95000
# Iter 37000, Minibatch Loss= 0.190314, Training Accuracy= 0.94000
# Iter 38000, Minibatch Loss= 0.104409, Training Accuracy= 0.97000
# Iter 39000, Minibatch Loss= 0.171623, Training Accuracy= 0.92000
# Iter 40000, Minibatch Loss= 0.124851, Training Accuracy= 0.96000
# Iter 41000, Minibatch Loss= 0.187506, Training Accuracy= 0.95000
# Iter 42000, Minibatch Loss= 0.138052, Training Accuracy= 0.95000
# Iter 43000, Minibatch Loss= 0.125321, Training Accuracy= 0.96000
# Iter 44000, Minibatch Loss= 0.055781, Training Accuracy= 0.98000
# Iter 45000, Minibatch Loss= 0.089734, Training Accuracy= 0.98000
# Iter 46000, Minibatch Loss= 0.118615, Training Accuracy= 0.95000
# Iter 47000, Minibatch Loss= 0.121494, Training Accuracy= 0.97000
# Iter 48000, Minibatch Loss= 0.277026, Training Accuracy= 0.93000
# Iter 49000, Minibatch Loss= 0.164722, Training Accuracy= 0.95000
# Iter 50000, Minibatch Loss= 0.205669, Training Accuracy= 0.94000
# Iter 51000, Minibatch Loss= 0.094950, Training Accuracy= 0.99000
# Iter 52000, Minibatch Loss= 0.189072, Training Accuracy= 0.91000
# Iter 53000, Minibatch Loss= 0.213075, Training Accuracy= 0.93000
# Iter 54000, Minibatch Loss= 0.098526, Training Accuracy= 0.96000
# Iter 55000, Minibatch Loss= 0.100745, Training Accuracy= 0.93000
# Iter 56000, Minibatch Loss= 0.091957, Training Accuracy= 0.97000
# Iter 57000, Minibatch Loss= 0.273804, Training Accuracy= 0.88000
# Iter 58000, Minibatch Loss= 0.124681, Training Accuracy= 0.95000
# Iter 59000, Minibatch Loss= 0.119902, Training Accuracy= 0.97000
# Iter 60000, Minibatch Loss= 0.075208, Training Accuracy= 0.98000
# Iter 61000, Minibatch Loss= 0.122685, Training Accuracy= 0.96000
# Iter 62000, Minibatch Loss= 0.120057, Training Accuracy= 0.97000
# Iter 63000, Minibatch Loss= 0.118782, Training Accuracy= 0.98000
# Iter 64000, Minibatch Loss= 0.038494, Training Accuracy= 0.99000
# Iter 65000, Minibatch Loss= 0.104794, Training Accuracy= 0.98000
# Iter 66000, Minibatch Loss= 0.135522, Training Accuracy= 0.97000
# Iter 67000, Minibatch Loss= 0.201660, Training Accuracy= 0.93000
# Iter 68000, Minibatch Loss= 0.152450, Training Accuracy= 0.96000
# Iter 69000, Minibatch Loss= 0.159187, Training Accuracy= 0.94000
# Iter 70000, Minibatch Loss= 0.097340, Training Accuracy= 0.96000
# Iter 71000, Minibatch Loss= 0.127897, Training Accuracy= 0.97000
# Iter 72000, Minibatch Loss= 0.140419, Training Accuracy= 0.94000
# Iter 73000, Minibatch Loss= 0.153236, Training Accuracy= 0.94000
# Iter 74000, Minibatch Loss= 0.143100, Training Accuracy= 0.96000
# Iter 75000, Minibatch Loss= 0.082870, Training Accuracy= 0.98000
# Iter 76000, Minibatch Loss= 0.112798, Training Accuracy= 0.97000
# Iter 77000, Minibatch Loss= 0.108888, Training Accuracy= 0.98000
# Iter 78000, Minibatch Loss= 0.121067, Training Accuracy= 0.97000
# Iter 79000, Minibatch Loss= 0.116977, Training Accuracy= 0.97000
# Iter 80000, Minibatch Loss= 0.069827, Training Accuracy= 0.98000
# Iter 81000, Minibatch Loss= 0.093979, Training Accuracy= 0.97000
# Iter 82000, Minibatch Loss= 0.056514, Training Accuracy= 0.98000
# Iter 83000, Minibatch Loss= 0.077201, Training Accuracy= 0.98000
# Iter 84000, Minibatch Loss= 0.059232, Training Accuracy= 0.98000
# Iter 85000, Minibatch Loss= 0.162675, Training Accuracy= 0.95000
# Iter 86000, Minibatch Loss= 0.108617, Training Accuracy= 0.97000
# Iter 87000, Minibatch Loss= 0.106626, Training Accuracy= 0.97000
# Iter 88000, Minibatch Loss= 0.063700, Training Accuracy= 0.97000
# Iter 89000, Minibatch Loss= 0.063898, Training Accuracy= 0.98000
# Iter 90000, Minibatch Loss= 0.080549, Training Accuracy= 0.97000
# Iter 91000, Minibatch Loss= 0.047354, Training Accuracy= 1.00000
# Iter 92000, Minibatch Loss= 0.163885, Training Accuracy= 0.93000
# Iter 93000, Minibatch Loss= 0.048886, Training Accuracy= 0.98000
# Iter 94000, Minibatch Loss= 0.122002, Training Accuracy= 0.97000
# Iter 95000, Minibatch Loss= 0.050695, Training Accuracy= 0.99000
# Iter 96000, Minibatch Loss= 0.205640, Training Accuracy= 0.93000
# Iter 97000, Minibatch Loss= 0.177058, Training Accuracy= 0.96000
# Iter 98000, Minibatch Loss= 0.019510, Training Accuracy= 1.00000
# Iter 99000, Minibatch Loss= 0.140892, Training Accuracy= 0.95000
# Iter 100000, Minibatch Loss= 0.054385, Training Accuracy= 0.97000
# Iter 101000, Minibatch Loss= 0.113903, Training Accuracy= 0.96000
# Iter 102000, Minibatch Loss= 0.066457, Training Accuracy= 0.97000
# Iter 103000, Minibatch Loss= 0.170474, Training Accuracy= 0.95000
# Iter 104000, Minibatch Loss= 0.036180, Training Accuracy= 0.99000
# Iter 105000, Minibatch Loss= 0.258173, Training Accuracy= 0.94000
# Iter 106000, Minibatch Loss= 0.144614, Training Accuracy= 0.97000
# Iter 107000, Minibatch Loss= 0.072018, Training Accuracy= 0.97000
# Iter 108000, Minibatch Loss= 0.080132, Training Accuracy= 0.96000
# Iter 109000, Minibatch Loss= 0.093421, Training Accuracy= 0.98000
# Iter 110000, Minibatch Loss= 0.038784, Training Accuracy= 0.99000
# Iter 111000, Minibatch Loss= 0.104451, Training Accuracy= 0.97000
# Iter 112000, Minibatch Loss= 0.019662, Training Accuracy= 1.00000
# Iter 113000, Minibatch Loss= 0.061332, Training Accuracy= 0.99000
# Iter 114000, Minibatch Loss= 0.043221, Training Accuracy= 0.97000
# Iter 115000, Minibatch Loss= 0.133865, Training Accuracy= 0.97000
# Iter 116000, Minibatch Loss= 0.049730, Training Accuracy= 0.97000
# Iter 117000, Minibatch Loss= 0.037719, Training Accuracy= 0.99000
# Iter 118000, Minibatch Loss= 0.152305, Training Accuracy= 0.96000
# Iter 119000, Minibatch Loss= 0.062867, Training Accuracy= 0.98000
# Iter 120000, Minibatch Loss= 0.037365, Training Accuracy= 0.99000
# Iter 121000, Minibatch Loss= 0.097558, Training Accuracy= 0.95000
# Iter 122000, Minibatch Loss= 0.046835, Training Accuracy= 0.99000
# Iter 123000, Minibatch Loss= 0.080803, Training Accuracy= 0.98000
# Iter 124000, Minibatch Loss= 0.125636, Training Accuracy= 0.96000
# Iter 125000, Minibatch Loss= 0.090471, Training Accuracy= 0.96000
# Iter 126000, Minibatch Loss= 0.032819, Training Accuracy= 0.99000
# Iter 127000, Minibatch Loss= 0.101481, Training Accuracy= 0.96000
# Iter 128000, Minibatch Loss= 0.044269, Training Accuracy= 0.98000
# Iter 129000, Minibatch Loss= 0.086700, Training Accuracy= 0.97000
# Iter 130000, Minibatch Loss= 0.088646, Training Accuracy= 0.96000
# Iter 131000, Minibatch Loss= 0.086258, Training Accuracy= 0.98000
# Iter 132000, Minibatch Loss= 0.056340, Training Accuracy= 1.00000
# Iter 133000, Minibatch Loss= 0.035365, Training Accuracy= 0.99000
# Iter 134000, Minibatch Loss= 0.079998, Training Accuracy= 0.97000
# Iter 135000, Minibatch Loss= 0.025265, Training Accuracy= 0.99000
# Iter 136000, Minibatch Loss= 0.050609, Training Accuracy= 0.98000
# Iter 137000, Minibatch Loss= 0.105459, Training Accuracy= 0.96000
# Iter 138000, Minibatch Loss= 0.083331, Training Accuracy= 0.97000
# Iter 139000, Minibatch Loss= 0.094984, Training Accuracy= 0.98000
# Iter 140000, Minibatch Loss= 0.039442, Training Accuracy= 0.99000
# Iter 141000, Minibatch Loss= 0.015746, Training Accuracy= 1.00000
# Iter 142000, Minibatch Loss= 0.020163, Training Accuracy= 1.00000
# Iter 143000, Minibatch Loss= 0.092861, Training Accuracy= 0.98000
# Iter 144000, Minibatch Loss= 0.086262, Training Accuracy= 0.97000
# Iter 145000, Minibatch Loss= 0.022402, Training Accuracy= 0.99000
# Iter 146000, Minibatch Loss= 0.082680, Training Accuracy= 0.97000
# Iter 147000, Minibatch Loss= 0.079210, Training Accuracy= 0.97000
# Iter 148000, Minibatch Loss= 0.065812, Training Accuracy= 0.99000
# Iter 149000, Minibatch Loss= 0.069997, Training Accuracy= 0.97000
# Testing Accuracy: 0.9744
